# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/user/Downloads/world_population_.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.300000e+02     2.330000e+02     2.300000e+02
# mean   117.500000     3.463225e+07     3.360071e+07     3.206600e+07
# std     67.694165     1.378892e+08     1.358732e+08     1.315071e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.064710e+05     3.942950e+05
# 50%    117.500000     5.762857e+06     5.456681e+06     5.244415e+06
# 75%    175.750000     2.265372e+07     2.152263e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.270000e+02     2.270000e+02     2.290000e+02     2.290000e+02
# mean      3.027016e+07     2.684050e+07     1.933046e+07     1.628288e+07
# std       1.260742e+08     1.133525e+08     8.130962e+07     6.934547e+07
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
df.sort_values(by="World Population Percentage", ascending=False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# ...

# %%
df.corr(numeric_only = True)
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Rank                         1.000000        -0.357989        -0.356283
# 2022 Population             -0.357989         1.000000         0.999946
# 2020 Population             -0.356283         0.999946         1.000000
# 2015 Population             -0.352850         0.999492         0.999764
# 2010 Population             -0.350009         0.998633         0.999108
# 2000 Population             -0.342095         0.994602         0.995582
# 1990 Population             -0.333014         0.991124         0.992557
# 1980 Population             -0.328620         0.986675         0.988392
# 1970 Population             -0.335737         0.973135         0.975245
# Area (km²)                  -0.384854         0.452812         0.454902
# Density (per km²)            0.128994        -0.028761        -0.027802
# Growth Rate                 -0.220197        -0.022059        -0.025976
# ...

# %%
sns.heatmap(df.corr(numeric_only = True) , annot = True)
# %matplotlib inline
plt.rcParams['figure.figsize'] = (17,6)
plt.show()

# %%
df
# Out:
#      Rank CCA3            Country           Capital  Continent  \
# 0      36  AFG        Afghanistan             Kabul        NaN
# 1     138  ALB            Albania            Tirana        NaN
# 2      34  DZA            Algeria           Algiers        NaN
# 3     213  ASM     American Samoa         Pago Pago        NaN
# 4     203  AND            Andorra  Andorra la Vella        NaN
# ..    ...  ...                ...               ...        ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu        NaN
# 230   172  ESH     Western Sahara          El Aaiún        NaN
# 231    46  YEM              Yemen             Sanaa        NaN
# 232    63  ZMB             Zambia            Lusaka        NaN
# 233    74  ZWE           Zimbabwe            Harare        NaN
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# ...

# %%
df.groupby('Country').mean(numeric_only=True).sort_values(by="2022 Population",ascending=False)
# Out:
#                 Rank  Continent  2022 Population  2020 Population  \
# Country
# China            1.0        NaN     1.425887e+09     1.424930e+09
# India            2.0        NaN     1.417173e+09     1.396387e+09
# United States    3.0        NaN     3.382899e+08     3.359420e+08
# Indonesia        4.0        NaN     2.755013e+08     2.718580e+08
# Pakistan         5.0        NaN     2.358249e+08     2.271967e+08
# ...              ...        ...              ...              ...
# Vatican City   234.0        NaN     5.100000e+02     5.200000e+02
# Eswatini       159.0        NaN              NaN     1.180655e+06
# Norway         120.0        NaN              NaN     5.379839e+06
# Palau          222.0        NaN              NaN     1.797200e+04
# Timor-Leste    155.0        NaN              NaN     1.299995e+06
#
#                2015 Population  2010 Population  2000 Population  \
# Country
# China             1.393715e+09     1.348191e+09     1.264099e+09
# ...

# %%
# How the top 10 most populated countries have increased in population over time

# %%
df2 = df.groupby('Country')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean().sort_values(by="2022 Population",ascending=False).head(10)
df2
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Country
# China              822534450.0      982372466.0     1.153704e+09
# India              557501301.0              NaN              NaN
# United States      200328340.0      223140018.0     2.480837e+08
# Indonesia          115228394.0      148177096.0     1.821599e+08
# Pakistan            59290872.0       80624057.0     1.154141e+08
# Nigeria             55569264.0       72951439.0     9.521426e+07
# Brazil              96369875.0      122288383.0     1.507064e+08
# Bangladesh          67541860.0       83929765.0     1.071477e+08
# Russia             130093010.0      138257420.0     1.480057e+08
# Mexico              50289306.0       67705186.0     8.172043e+07
#
#                2000 Population  2010 Population  2015 Population  \
# Country
# China             1.264099e+09     1.348191e+09     1.393715e+09
# India             1.059634e+09     1.240614e+09     1.322867e+09
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df3 = df2.transpose()
df3
# Out:
# Country                 China         India  United States    Indonesia  \
# 1970 Population  8.225344e+08  5.575013e+08    200328340.0  115228394.0
# 1980 Population  9.823725e+08           NaN    223140018.0  148177096.0
# 1990 Population  1.153704e+09           NaN    248083732.0  182159874.0
# 2000 Population  1.264099e+09  1.059634e+09    282398554.0  214072421.0
# 2010 Population  1.348191e+09  1.240614e+09    311182845.0  244016173.0
# 2015 Population  1.393715e+09  1.322867e+09    324607776.0  259091970.0
# 2020 Population  1.424930e+09  1.396387e+09    335942003.0  271857970.0
# 2022 Population  1.425887e+09  1.417173e+09    338289857.0  275501339.0
#
# Country             Pakistan      Nigeria       Brazil   Bangladesh  \
# 1970 Population   59290872.0   55569264.0   96369875.0   67541860.0
# 1980 Population   80624057.0   72951439.0  122288383.0   83929765.0
# 1990 Population  115414069.0   95214257.0  150706446.0  107147651.0
# ...

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
# Open Circles = Outliers
